# %% [markdown]
# ## Statistics Advanced - 1
#
# > Assignment Code: DA-AG-006

# %% [markdown]
# # Question 1: What is a random variable in probability theory?

# %% [markdown]
# > A set of possible values from a random experiment.
#
# > A random variable's value is unknown.
#
# > A function that assign valued to each of experiment outcome.

# %% [markdown]
# # Question 2: What are the types of random variables?

# %% [markdown]
# ![image.png](attachment:ea37a892-ddc7-4754-9a5f-932d09b1a4cb.png)
#
# --> A Discrete Random Variable takes on a finite or countably infinite number of values. The probability function associated with a discrete random variable is called as Probability Mass Function (PMF).
#
# --> A Continuous Random Variable takes on an infinite number of values. The probability function associated with it is said to be Probability Density Function (PDF).

# %% [markdown]
# # Question 3: Explain the difference between discrete and continuous distributions.

# %% [markdown]
# --> Continuous uniform distribution is a probability distribution in which all outcomes are equally likely within a specified interval [a,b]. In other words, the probability density function (PDF) is constant over this interval, and the distribution is defined by the two parameters a and b, which are the lower and upper bounds, respectively.
#
# --> Discrete uniform distribution is a kind of probability distribution in which every possible result has equal likelihood of occurrence. When there are limited possibilities and every one of them is equally likely, this distribution is applied.
#
# --> Conclusion:
# >The difference between continuous and discrete uniform distributions lies in their fundamental approach to representing data. Continuous uniform distributions encompass outcomes across a continuous range, ideal for scenarios where variables can take any value within a specified interval. On the other hand, discrete uniform distributions involve outcomes that are distinct and separate, suited for scenarios where variables can only take on a finite set of values with equal probability.

# %% [markdown]
# # Question 4: What is a binomial distribution, and how is it used in probability?

# %% [markdown]
# -->The binomial distribution is a discrete probability distribution that models the number of successes in a fixed number of independent trials, where each trial has only two possible outcomes (success or failure) and a constant probability of success.
#
# The binomial distribution is a powerful tool used in probability theory and statistics to calculate the likelihood of a specific number of successful outcomes in various real-world scenarios that meet the following criteria:
#
# >Fixed Number of Trials: The experiment consists of a predetermined number of repetitions.
#
# >Two Possible Outcomes: Each trial results in either a "success" or a "failure".
#
# >Independent Trials: The outcome of one trial does not affect the outcome of any other trial.
#
# >Constant Probability: The probability of success remains the same for every trial

# %% [markdown]
# # Question 5: What is the standard normal distribution, and why is it important?

# %% [markdown]
# --> The standard normal distribution (or z-distribution) is a specific type of normal distribution that has a mean of 0 and a standard deviation of 1. Its shape is a symmetrical, bell-shaped curve, with the total area under the curve representing a total probability of 1 (or 100%).
#
# The primary importance of the standard normal distribution lies in its ability to act as a universal template for all other normal distributions. This standardization allows for meaningful comparisons and probability calculations across datasets with vastly different means and standard deviations.

# %% [markdown]
# # Question 6: What is the Central Limit Theorem (CLT), and why is it critical in statistics?

# %% [markdown]
# --> The Central Limit Theorem (CLT) is a fundamental statistical theory stating that, given a sufficiently large sample size, the sampling distribution of the mean for a variable will approximate a normal distribution, regardless of the shape of the original population distribution.
#
# The Central Limit Theorem is the cornerstone of modern inferential statistics, enabling the use of probability theory to make inferences about large populations based on smaller samples.

# %% [markdown]
# # Question 7: What is the significance of confidence intervals in statistical analysis?

# %% [markdown]
# --> Confidence intervals are a vital component of statistical analysis because they quantify the uncertainty of estimates, provide a range of plausible values for an unknown population parameter, and help researchers assess both the precision and practical significance of their findings.

# %% [markdown]
# # Question 8: What is the concept of expected value in a probability distribution?

# %% [markdown]
# --> The expected value (or mean) of a probability distribution is the long-term average outcome of a random variable if an experiment or procedure with a numerical outcome is repeated many times. It is a single number that summarizes the center or central tendency of the entire distribution.
#
# The expected value is essentially a weighted average of all possible outcomes, where each outcome is weighted by its probability of occurrence.

# %% [markdown]
# # Question 9: Write a Python program to generate 1000 random numbers from a normal distribution with mean = 50 and standard deviation = 5. Compute its mean and standard deviation using NumPy, and draw a histogram to visualize the distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

n = 1000
mean = 50
std = 50

random_no = np.random.normal(loc=mean, scale=std, size=n)
random_no_mean = np.mean(random_no)
random_no_std = np.std(random_no)

print("Computed Mean:", random_no_mean)
print("Computed Standard Deviation:", random_no_std)

sns.histplot(random_no, kde=True)
plt.title("Normal Distribution of 1000 random numbers")
plt.xlabel("value")
plt.ylabel("count")
# Out:
# Computed Mean: 51.12926944098398
# Computed Standard Deviation: 49.36150170760914
# Text(0, 0.5, 'count')

# %% [markdown]
# # Question 10: You are working as a data analyst for a retail company. The company has collected daily sales data for 2 years and wants you to identify the overall sales trend.
#
# > daily_sales = [220, 245, 210, 265, 230, 250, 260, 275, 240, 255, 235, 260, 245, 250, 225, 270, 265, 255, 250, 260]
#
# >> Explain how you would apply the Central Limit Theorem to estimate the average sales
# with a 95% confidence interval.
#
# >> Write the Python code to compute the mean sales and its confidence interval.

# %%
import numpy as np
from scipy import stats

daily_sales = [220, 245, 210, 265, 230, 250, 260, 275, 240, 255, 235, 260, 245, 250, 225, 270, 265, 255, 250, 260]

data = np.array(daily_sales)

sample_mean = np.mean(data)

sample_std = np.std(data, ddof=1)

confidence_level = 0.95
degrees_of_freedom = len(data) - 1

critical_t_value = stats.t.ppf((1 + confidence_level) / 2, degrees_of_freedom)

margin_of_error = critical_t_value * (sample_std / np.sqrt(len(data)))

confidence_interval_lower = sample_mean - margin_of_error
confidence_interval_upper = sample_mean + margin_of_error

print(f"Sample Mean Sales: {sample_mean}\n")
print(f"Sample Standard Deviation: {sample_std}\n")
print(f"Critical t-value: {critical_t_value}\n")
print(f"Margin of Error: {margin_of_error}\n")
print(f"95% Confidence Interval for Mean Sales: ({confidence_interval_lower}, {confidence_interval_upper})")
# Out:
# Sample Mean Sales: 248.25
#
# Sample Standard Deviation: 17.26534405284638
#
# Critical t-value: 2.093024054408263
#
# Margin of Error: 8.080429748528413
#
# 95% Confidence Interval for Mean Sales: (240.16957025147158, 256.3304297485284)

# %% [markdown]
# We can be 95% confident that the true average daily sales for the company falls somewhere between 240.17 and 256.33 units.
